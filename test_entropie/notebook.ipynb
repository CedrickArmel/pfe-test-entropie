# %%
import pandas as pd
import numpy as np
import random
from  math import log2
from collections import Counter
from cadsgen import generate_payload_agri_parcel_record
from entropies import shannon_entropy_kde

# %%
def generate_white_noise(num_samples, amplitude):
    dataset = []
    for _ in range(num_samples):
        sample = random.uniform(-amplitude, amplitude)
        dataset.append(sample)
    return dataset

# %%
records = []
for _ in range(100) :
    records.append(generate_payload_agri_parcel_record())
cads = pd.DataFrame(records)

# %%
filtered_cads = cads.select_dtypes(include=[np.number])

# %%
def initialiser_dictionnaire(liste_cles):
    dictionnaire = {cle: 0 for cle in liste_cles}
    return dictionnaire

# %%
def sampling_kg(XM, players:dict, K) :
    ply = list(players.keys())
    m = len(ply)
    sv = initialiser_dictionnaire(ply)

    # Pour chaque échantillon
    for _ in range(K):
        coalition = np.random.choice(ply, size=np.random.randint(2, m+1), replace=False)
        features = []
        for player in coalition :
            features += players[player]
        coalition_accuracy_val = shannon_entropy_kde(XM[features].values)
        print('coalition_accuracy_val : ', coalition_accuracy_val)

        for player in coalition :
            coalition_without_player = [p for p in coalition if p != player]
            features_wh_player = []
            for player in coalition_without_player :
                features_wh_player += players[player]
            coalition_without_player_accuracy_val = shannon_entropy_kde(XM[features_wh_player].values)
            contribution = coalition_accuracy_val - coalition_without_player_accuracy_val
            print('coalition_without_player_accuracy_val : ', coalition_without_player_accuracy_val)
            print('contribtion : ', contribution)

            sv[player] += contribution / K
    return sv

# %%
players = dict(player1 = list(cads.columns)[:5],
               player2= list(cads.columns)[5:10],
               player3= list(cads.columns)[10:15],
               player4= list(cads.columns)[15:20],
               player5= list(cads.columns)[20:30],
               player6= list(cads.columns)[30:40],
               player7= list(cads.columns)[40:])

players_f = dict(player1 = list(filtered_cads.columns)[:5],
               player2= list(filtered_cads.columns)[5:10],
               player3= list(filtered_cads.columns)[10:])

player_df = dict(player1 = ['first'],
                 player2 = ['scond'])

# %%
df = pd.DataFrame(dict(first = a, scond = b))

# %%
df
# Out:
#     first  scond
# 0       1      1
# 1       2      3
# 2       3      5
# 3       4      7
# 4       5      9
# ..    ...    ...
# 94     95    189
# 95     96    191
# 96     97    193
# 97     98    195
# 98     99    197
#
# [99 rows x 2 columns]

# %%
sampling_kg(df, player_df, 1000)
# Out:
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# coalition_accuracy_val :  0.691
# contribtion :  0.0
# contribtion :  0.0
# ...

# %%
0....
# Out:
# 0.0

# %%
np.array([np.nan, 2]).mean()
# Out:
# nan
